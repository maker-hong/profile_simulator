# %%
from tkinter import *
from tkinter import ttk

# %%
sim=Tk()

sim.title("Profile Simulator v1.0")
sim.geometry("640x560+100+100")
sim.resizable(False, False)

label1 = ttk.Label(sim, text = "Welcome to Profile Simulator!", font=("Calibri","16"))
label1.place(x= 180, y=10)

def open_file():
    print("파일 업로드 기능을 추가하세요")

def sample():
    print("샘플 데이터 업로드 기능을 추가하세요")

def cali():  
    print("캘리브레이션 기능을 추가하세요")
    
def taper_y():  
    print("테이퍼롤 적용 기능을 추가하세요")
    
def taper_n():  
    print("테이퍼롤 적용 기능을 추가하세요")
    
def shift():  
    print("shift 패턴 적용 기능을 추가하세요")

def init_crown():  
    print("initial crown 적용 기능을 추가하세요")

def simulation():  
    print("simulation 적용 기능을 추가하세요")


# btn1 = Button(sim, padx=10, pady= 10, fg="green", bg="yellow", text="Open")

label2 = Label(sim, text= "Upload File")
label2.place(x= 40, y=53)

b_open = Button(sim, width=10, height= 1, text="Open", command = open_file)
b_open.place(x=120,y=50)

label3 = Label(sim, text= "Sample Data")
label3.place(x= 40, y=83)

b_sample = Button(sim, width=10, height= 1, text="Upload", command = sample)
b_sample.place(x=120,y=80)

label4 = Label(sim, text= "Calibration")
label4.place(x= 40, y=113)

b_cali = Button(sim, width=10, height= 1, text="Start", command = cali)
b_cali.place(x=120,y=110)

label5 = Label(sim, text= "Tapered Roll")
label5.place(x= 330, y=53)

b_yes = Button(sim, width=10, height= 1, text="Yes", command = taper_y)
b_yes.place(x=420,y=50)

b_no = Button(sim, width=10, height= 1, text="No", command = taper_n)
b_no.place(x=500,y=50)

label6 = Label(sim, text= "Shift Pattern")
label6.place(x= 330, y=83)

combo = ttk.Combobox(sim)
combo['values'] = ("high carbon", "CGL", "EG", "API")
combo.current(0)
combo.place(x = 420, y=83)
combo.bind("<Button-1>", print("test"))

label7 = Label(sim, text= "Initial Crown")
label7.place(x= 330, y=113)

combo2 = ttk.Combobox(sim)
combo2['values'] = (0, 80, -80, -120, 120)
combo2.current(0)
combo2.place(x = 420, y=113)

label8 = Label(sim, text= "Simulation")
label8.place(x= 40, y=173)

b_sim = Button(sim, width=10, height= 1, text="Start", command = simulation)
b_sim.place(x=120,y=170)

img = PhotoImage(file="profile_image.png")
label9 = Label(sim, image=img)
label9.pack(side="bottom")

sim.mainloop()
# Out:
# test
# 파일 업로드 기능을 추가하세요
# 샘플 데이터 업로드 기능을 추가하세요
# 캘리브레이션 기능을 추가하세요
# simulation 적용 기능을 추가하세요
